# %% [markdown]
# #### Load in dataset

# %%
import pandas as pd
from tabulate import tabulate
import numpy as np
import os
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

#--- Custom Functions as defined by the user ---
import sys
sys.path.append(os.path.abspath("../tools"))
import functions

# %%
# Load in dataset
# Update the file path below to the correct location of your CSV file
data = pd.read_csv("../../../../data/finaldatasets/testdata/finalfr/Treedataupdate1.csv", header=0, sep=",")
# Out:
# /tmp/ipykernel_342271/3372099482.py:3: DtypeWarning: Columns (6,7,12,13,14,15,16,17,20,22,23,29,31,33,34,35,36,37,44,45,51,52,56,57,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../../../../data/finaldatasets/testdata/finalfr/Treedataupdate1.csv", header=0, sep=",")

# %%
functions.summarize_dataframe(data)
# Out:
# | variable                                              | dtype   |   count |   pct_complete |   n_unique |
# |-------------------------------------------------------|---------|---------|----------------|------------|
# | id                                                    | int64   |   69430 |          100   |      69036 |
# | EvapS2                                                | float64 |   69430 |          100   |       1155 |
# | pre9                                                  | float64 |   69428 |          100   |        639 |
# | pre8                                                  | float64 |   69428 |          100   |        632 |
# | pre7                                                  | float64 |   69428 |          100   |        650 |
# | pre6                                                  | float64 |   69428 |          100   |        674 |
# | pre5                                                  | float64 |   69428 |          100   |        660 |
# | pre4                                                  | float64 |   69428 |          100   |        659 |
# | pre3                                                  | float64 |   69428 |          100   |        654 |
# | pre2                                                  | float64 |   69428 |          100   |        644 |
# | pre1                                                  | float64 |   69428 |          100   |        632 |
# | temp9                                                 | float64 |   69428 |          100   |        684 |
# | temp8                                                 | float64 |   69428 |          100   |        679 |
# | temp7                                                 | float64 |   69428 |          100   |        678 |
# | temp6                                                 | float64 |   69428 |          100   |        679 |
# | temp5                                                 | float64 |   69428 |          100   |        678 |
# | temp4                                                 | float64 |   69428 |          100   |        677 |
# | temp3                                                 | float64 |   69428 |          100   |        673 |
# | temp2                                                 | float64 |   69428 |          100   |        660 |
# | temp1                                                 | float64 |   69428 |          100   |        652 |
# | longitude_jittered                                    | float64 |   69430 |          100   |      69430 |
# | latitude_jittered                                     | float64 |   69430 |          100   |      69430 |
# | jitter_radius_km                                      | float64 |   69430 |          100   |         88 |
# | group_id                                              | object  |   69430 |          100   |        572 |
# | gdp_per_capita                                        | int64   |   69430 |          100   |        496 |
# | EvapS1                                                | float64 |   69430 |          100   |       1155 |
# | EvapS3                                                | float64 |   69430 |          100   |       1155 |
# | year                                                  | int64   |   69430 |          100   |         15 |
# | EvapS4                                                | float64 |   69430 |          100   |       1146 |
# | Evap8                                                 | float64 |   69430 |          100   |        565 |
# | Evap7                                                 | float64 |   69430 |          100   |        565 |
# | Evap6                                                 | float64 |   69430 |          100   |        565 |
# | Evap5                                                 | float64 |   69430 |          100   |        565 |
# | Evap4                                                 | float64 |   69430 |          100   |        565 |
# | Evap3                                                 | float64 |   69430 |          100   |        565 |
# | Evap2                                                 | float64 |   69430 |          100   |        565 |
# | Evap1                                                 | float64 |   69430 |          100   |        565 |
# | sowing_year                                           | int64   |   69430 |          100   |         15 |
# | Trans9                                                | float64 |   69430 |          100   |       1130 |
# | Trans8                                                | float64 |   69430 |          100   |       1130 |
# | Trans7                                                | float64 |   69430 |          100   |       1116 |
# | Trans6                                                | float64 |   69430 |          100   |       1107 |
# | Trans5                                                | float64 |   69430 |          100   |       1068 |
# | Trans4                                                | float64 |   69430 |          100   |       1075 |
# | Trans3                                                | float64 |   69430 |          100   |       1127 |
# | Trans2                                                | float64 |   69430 |          100   |       1135 |
# | Trans1                                                | float64 |   69430 |          100   |       1135 |
# | EvapS9                                                | float64 |   69430 |          100   |       1153 |
# | EvapS8                                                | float64 |   69430 |          100   |       1155 |
# | EvapS7                                                | float64 |   69430 |          100   |       1145 |
# | EvapS6                                                | float64 |   69430 |          100   |       1135 |
# | EvapS5                                                | float64 |   69430 |          100   |       1118 |
# | Data.ID                                               | object  |   69430 |          100   |         51 |
# | Evap9                                                 | float64 |   69430 |          100   |        565 |
# | pr_irrigated                                          | float64 |   69428 |          100   |        191 |
# | Conversion.for.latitude                               | float64 |   69430 |          100   |        237 |
# | start_date                                            | int64   |   69430 |          100   |          7 |
# | Grain.yield..tons.ha.1.                               | float64 |   69430 |          100   |      14855 |
# | end_date                                              | int64   |   69430 |          100   |         10 |
# | Elevation                                             | int64   |   69430 |          100   |        196 |
# | Observation.period                                    | int64   |   69430 |          100   |         15 |
# | Location.source                                       | object  |   69430 |          100   |          9 |
# | Conversion.for.longitude                              | float64 |   69430 |          100   |        237 |
# | Longitude..E.W.                                       | object  |   69430 |          100   |        254 |
# | Latitude..N.S.                                        | object  |   69430 |          100   |        251 |
# | Continent                                             | object  |   69430 |          100   |          6 |
# | Country                                               | object  |   69430 |          100   |         37 |
# | AEZ                                                   | float64 |   69430 |          100   |         31 |
# | Location                                              | object  |   69430 |          100   |        231 |
# | SoilM5                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM8                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM7                                                | float64 |   69343 |           99.9 |       1136 |
# | SoilM6                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM9                                                | float64 |   69343 |           99.9 |       1138 |
# | SoilM4                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM3                                                | float64 |   69343 |           99.9 |       1138 |
# | SoilM2                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM1                                                | float64 |   69343 |           99.9 |       1139 |
# | NDVI3                                                 | float64 |   69197 |           99.7 |        569 |
# | NDVI5                                                 | float64 |   69198 |           99.7 |        578 |
# | NDVI6                                                 | float64 |   69245 |           99.7 |        597 |
# | NDVI2                                                 | float64 |   69200 |           99.7 |        593 |
# | NDVI1                                                 | float64 |   69152 |           99.6 |        568 |
# | State.Region.County.Province                          | object  |   69154 |           99.6 |        132 |
# | NDVI4                                                 | float64 |   69108 |           99.5 |        560 |
# | Soil.organic.carbon..g.C.kg.1.                        | float64 |   68989 |           99.4 |        232 |
# | Soil.pH                                               | float64 |   69003 |           99.4 |        133 |
# | Sand                                                  | float64 |   68918 |           99.3 |        160 |
# | Silt                                                  | float64 |   68918 |           99.3 |        141 |
# | Clay                                                  | float64 |   68918 |           99.3 |        118 |
# | Soil_N                                                | float64 |   68840 |           99.2 |        123 |
# | NDVI9                                                 | float64 |   67784 |           97.6 |        610 |
# | NDVI8                                                 | float64 |   67762 |           97.6 |        597 |
# | NDVI7                                                 | float64 |   67785 |           97.6 |        572 |
# | Year_x                                                | float64 |   65004 |           93.6 |         15 |
# | Use_per_area_of_cropland_._Pesticides_.total._.kg.ha. | float64 |   65004 |           93.6 |        107 |
# | Agricultural_Use_._Pesticides_.total._.t.             | float64 |   65004 |           93.6 |        123 |
# | Agricultural_Use_._Insecticides_.t.                   | float64 |   65004 |           93.6 |        123 |
# | Agricultural_Use_._Fungicides_and_Bactericides_.t.    | float64 |   64840 |           93.4 |        121 |
# | Agricultural_Use_._Herbicides_.t.                     | float64 |   64840 |           93.4 |        122 |
# | N.rate..kg.N.ha.1.                                    | float64 |   63611 |           91.6 |        196 |
# | drydays.annualsum.                                    | float64 |   62048 |           89.4 |        444 |
# | dryspells.5days.                                      | float64 |   62048 |           89.4 |        424 |
# | irr_end_date                                          | float64 |   61699 |           88.9 |         10 |
# | irr_start_date                                        | float64 |   61684 |           88.8 |          8 |
# | Wheat.Type                                            | object  |   55463 |           79.9 |          2 |
# | rainfed_start_date                                    | float64 |   54978 |           79.2 |          6 |
# | rainfed_end_date                                      | float64 |   54991 |           79.2 |          9 |
# | Agricultural_Use_._Rodenticides_.t.                   | float64 |   50406 |           72.6 |         57 |
# | Mean.annual.precipitation..mm.                        | float64 |   47530 |           68.5 |        255 |
# | Crop.variety                                          | object  |   46867 |           67.5 |        943 |
# | Irrigation..mm.                                       | object  |   45402 |           65.4 |         31 |
# | irrigation_applied                                    | object  |   45402 |           65.4 |          4 |
# | Pest.prescence....64                                  | object  |   44907 |           64.7 |          2 |
# | Irrigation.mm_clean                                   | float64 |   44622 |           64.3 |         26 |
# | Agricultural_Use_._Other_Pesticides_nes_.t.           | float64 |   39209 |           56.5 |         84 |
# | Soil.type                                             | object  |   36750 |           52.9 |         48 |
# | Harvesting.date.1                                     | object  |   35347 |           50.9 |        262 |
# | harvest_dayofyear                                     | float64 |   35315 |           50.9 |        158 |
# | harvest_date_clean                                    | object  |   35315 |           50.9 |        260 |
# | harvest_month                                         | float64 |   35315 |           50.9 |         12 |
# | harvest_week                                          | float64 |   35315 |           50.9 |         42 |
# | gdp                                                   | float64 |   20676 |           29.8 |        195 |
# | hdi                                                   | float64 |   20676 |           29.8 |        176 |
# | Treatment_Category                                    | object  |   18421 |           26.5 |         14 |
# | Treatment.type                                        | object  |   18421 |           26.5 |        945 |
# | Tillage.type                                          | object  |   17201 |           24.8 |         19 |
# | Treatment                                             | object  |   16052 |           23.1 |          2 |
# | Mean.annual.temperature..Â.C.                         | float64 |   15177 |           21.9 |        103 |
# | P.rate..kg.P.ha.1.                                    | float64 |   14532 |           20.9 |         61 |
# | N_Category                                            | object  |   11240 |           16.2 |         11 |
# | N.type                                                | object  |   11240 |           16.2 |        648 |
# | P.type                                                | object  |   10834 |           15.6 |         19 |
# | Emissions..yes.no.                                    | object  |   10772 |           15.5 |        737 |
# | emissions_flag                                        | object  |   10772 |           15.5 |          2 |
# | Water.regime                                          | object  |    8554 |           12.3 |          5 |
# | Plastic.film.mulching                                 | object  |    8232 |           11.9 |          2 |
# | GDDs                                                  | float64 |    6480 |            9.3 |        270 |
# | Pest.severity.score.......66                          | object  |    6029 |            8.7 |         60 |
# | Pest.severity.score.cleaned                           | float64 |    6029 |            8.7 |         58 |
# | Pest.detected...65                                    | object  |    6050 |            8.7 |          9 |
# | Planting.date.1                                       | object  |    4711 |            6.8 |        102 |
# | Planting_Week                                         | float64 |    4695 |            6.8 |         32 |
# | Planting_Month                                        | float64 |    4695 |            6.8 |         11 |
# | Planting_Day                                          | float64 |    4695 |            6.8 |         79 |
# | Planting.date                                         | object  |    4525 |            6.5 |         99 |

# %% [markdown]
# ### Evi

# %%
EVIdata = pd.read_csv("../../../../data/finaldatasets/covariates/Earthdata/covs/sebwheatdata-MOD13A3-061-results.csv", header=0, sep=",")

print("Data loaded successfully.")

functions.summarize_dataframe(EVIdata)
# Out:
# Data loaded successfully.
# | variable                                                                    | dtype   |   count |   pct_complete |   n_unique |
# |-----------------------------------------------------------------------------|---------|---------|----------------|------------|
# | ID                                                                          | int64   |   53816 |            100 |        248 |
# | Latitude                                                                    | float64 |   53816 |            100 |        237 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Possible_shadow                        | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Possible_snow/ice_Description          | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Possible_snow/ice                      | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Land/Water_Mask_Description            | object  |   53816 |            100 |          3 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Land/Water_Mask                        | object  |   53816 |            100 |          3 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Mixed_Clouds_Description               | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Mixed_Clouds                           | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Atmosphere_BRDF_Correction_Description | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Atmosphere_BRDF_Correction             | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Adjacent_cloud_detected_Description    | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Adjacent_cloud_detected                | object  |   53816 |            100 |          2 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Aerosol_Quantity_Description           | object  |   53816 |            100 |          4 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Aerosol_Quantity                       | object  |   53816 |            100 |          4 |
# | MOD13A3_061__1_km_monthly_VI_Quality_VI_Usefulness_Description              | object  |   53816 |            100 |         12 |
# | MOD13A3_061__1_km_monthly_VI_Quality_VI_Usefulness                          | object  |   53816 |            100 |         12 |
# | MOD13A3_061__1_km_monthly_VI_Quality_MODLAND_Description                    | object  |   53816 |            100 |          4 |
# | MOD13A3_061__1_km_monthly_VI_Quality_MODLAND                                | object  |   53816 |            100 |          4 |
# | MOD13A3_061__1_km_monthly_VI_Quality_bitmask                                | object  |   53816 |            100 |        215 |
# | MOD13A3_061__1_km_monthly_VI_Quality                                        | float64 |   53816 |            100 |        215 |
# | MOD13A3_061__1_km_monthly_EVI                                               | float64 |   53816 |            100 |       6804 |
# | MOD13A3_061_Sample_X_1km                                                    | float64 |   53816 |            100 |        215 |
# | MOD13A3_061_Line_Y_1km                                                      | float64 |   53816 |            100 |        204 |
# | MODIS_Tile                                                                  | object  |   53816 |            100 |         47 |
# | Date                                                                        | object  |   53816 |            100 |        217 |
# | Longitude                                                                   | float64 |   53816 |            100 |        237 |
# | MOD13A3_061__1_km_monthly_VI_Quality_Possible_shadow_Description            | object  |   53816 |            100 |          2 |

# %%
EVIdata["MOD13A3_061__1_km_monthly_VI_Quality_MODLAND_Description"].value_counts()
# Out:
# MOD13A3_061__1_km_monthly_VI_Quality_MODLAND_Description
# VI produced, good quality                              39902
# VI produced, but check other QA                        12483
# Pixel produced, but most probably cloudy                1397
# Pixel not produced due to other reasons than clouds       34
# Name: count, dtype: int64

# %%
EVIdata = EVIdata[
	~EVIdata["MOD13A3_061__1_km_monthly_VI_Quality_MODLAND_Description"].isin([
		"Pixel produced, but most probably cloudy",
		"Pixel not produced due to other reasons than clouds"
	])
]

# %%
EVI = EVIdata[["Date", "Longitude", "Latitude", "MOD13A3_061__1_km_monthly_EVI"]]

# %%
functions.summarize_dataframe(EVI)
# Out:
# | variable                      | dtype   |   count |   pct_complete |   n_unique |
# |-------------------------------|---------|---------|----------------|------------|
# | Date                          | object  |   52385 |            100 |        217 |
# | Longitude                     | float64 |   52385 |            100 |        237 |
# | Latitude                      | float64 |   52385 |            100 |        237 |
# | MOD13A3_061__1_km_monthly_EVI | float64 |   52385 |            100 |       6714 |

# %%
EVI.to_csv("EVI.csv", index=False)

# %%
def extract_weather_variable(df, evi_df, var_prefix="evi_", window_length=9):
    """
    Extract 9-month EVI windows using merge operations.
    
    Parameters:
    df: Main dataset with 'id', 'sowing_year', 'start_date', coordinates
    evi_df: EVI DataFrame with 'Date', 'Longitude', 'Latitude', 'MOD13A3_061__1_km_monthly_EVI'
    var_prefix: Prefix for output columns
    window_length: Number of months (default 9)
    
    Returns: DataFrame with id, sowing_year, and monthly EVI values
    """
    
    # Prepare EVI data
    evi = evi_df.copy()
    evi['Date'] = pd.to_datetime(evi['Date'])
    evi['year'] = evi['Date'].dt.year
    evi['month'] = evi['Date'].dt.month
    evi['Longitude'] = evi['Longitude'].round(4)
    evi['Latitude'] = evi['Latitude'].round(4)
    
    # Prepare main data
    main = df.copy()
    
    # Create all possible date combinations for each observation
    expanded_rows = []
    for _, row in main.iterrows():
        start_date = datetime(int(row['sowing_year']), int(row['start_date']), 1)
        
        for i in range(window_length):
            window_date = start_date + relativedelta(months=i)
            expanded_rows.append({
                'sowing_year': row['sowing_year'],
                'Conversion.for.longitude': row['Conversion.for.longitude'],
                'Conversion.for.latitude': row['Conversion.for.latitude'],
                'start_date': row['start_date'],
                'window_month': i + 1,
                'target_year': window_date.year,
                'target_month': window_date.month
            })
    
    expanded_df = pd.DataFrame(expanded_rows)
    
    # Merge with EVI data
    merged = expanded_df.merge(
        evi,
        left_on=['Conversion.for.longitude', 'Conversion.for.latitude', 'target_year', 'target_month'],
        right_on=['Longitude', 'Latitude', 'year', 'month'],
        how='left'
    )
    
    # Pivot to get monthly columns
    result = merged.pivot_table(
        index=['sowing_year', 'Conversion.for.longitude', 'Conversion.for.latitude', 'start_date'],
        columns='window_month',
        values='MOD13A3_061__1_km_monthly_EVI',
        aggfunc='first'
    ).reset_index()
    
    # Rename columns
    result.columns = ['sowing_year', 'Conversion.for.longitude', 'Conversion.for.latitude', 'start_date'] + [f"{var_prefix}{i}" for i in range(1, window_length + 1)]
    
    return result

# %%
result = extract_weather_variable(data, EVI, var_prefix='evi_', window_length=9)

# %%
result.to_csv("EVI.csv", index=False)

# %%
data1 = data.merge(result, on=['sowing_year', 'Conversion.for.longitude', 'Conversion.for.latitude', 'start_date'], how='left')

# %% [markdown]
# #### FPAR and LAI

# %%
LAIANDFPARdata = pd.read_csv("../../../../data/finaldatasets/covariates/Earthdata/covs/sebwheatdata-MCD15A2H-061-results.csv", header=0, sep=",")

# %%
functions.summarize_dataframe(data1)
# Out:
# | variable                                              | dtype   |   count |   pct_complete |   n_unique |
# |-------------------------------------------------------|---------|---------|----------------|------------|
# | id                                                    | int64   |   69430 |          100   |      69036 |
# | EvapS3                                                | float64 |   69430 |          100   |       1155 |
# | EvapS1                                                | float64 |   69430 |          100   |       1155 |
# | pre9                                                  | float64 |   69428 |          100   |        639 |
# | pre8                                                  | float64 |   69428 |          100   |        632 |
# | pre7                                                  | float64 |   69428 |          100   |        650 |
# | pre6                                                  | float64 |   69428 |          100   |        674 |
# | pre5                                                  | float64 |   69428 |          100   |        660 |
# | pre4                                                  | float64 |   69428 |          100   |        659 |
# | pre3                                                  | float64 |   69428 |          100   |        654 |
# | pre2                                                  | float64 |   69428 |          100   |        644 |
# | pre1                                                  | float64 |   69428 |          100   |        632 |
# | temp9                                                 | float64 |   69428 |          100   |        684 |
# | temp8                                                 | float64 |   69428 |          100   |        679 |
# | temp7                                                 | float64 |   69428 |          100   |        678 |
# | temp6                                                 | float64 |   69428 |          100   |        679 |
# | temp5                                                 | float64 |   69428 |          100   |        678 |
# | temp4                                                 | float64 |   69428 |          100   |        677 |
# | temp3                                                 | float64 |   69428 |          100   |        673 |
# | temp2                                                 | float64 |   69428 |          100   |        660 |
# | temp1                                                 | float64 |   69428 |          100   |        652 |
# | longitude_jittered                                    | float64 |   69430 |          100   |      69430 |
# | latitude_jittered                                     | float64 |   69430 |          100   |      69430 |
# | jitter_radius_km                                      | float64 |   69430 |          100   |         88 |
# | group_id                                              | object  |   69430 |          100   |        572 |
# | EvapS2                                                | float64 |   69430 |          100   |       1155 |
# | EvapS4                                                | float64 |   69430 |          100   |       1146 |
# | year                                                  | int64   |   69430 |          100   |         15 |
# | EvapS5                                                | float64 |   69430 |          100   |       1118 |
# | Evap9                                                 | float64 |   69430 |          100   |        565 |
# | Evap8                                                 | float64 |   69430 |          100   |        565 |
# | Evap7                                                 | float64 |   69430 |          100   |        565 |
# | Evap6                                                 | float64 |   69430 |          100   |        565 |
# | Evap5                                                 | float64 |   69430 |          100   |        565 |
# | Evap4                                                 | float64 |   69430 |          100   |        565 |
# | Evap3                                                 | float64 |   69430 |          100   |        565 |
# | Evap2                                                 | float64 |   69430 |          100   |        565 |
# | Evap1                                                 | float64 |   69430 |          100   |        565 |
# | sowing_year                                           | int64   |   69430 |          100   |         15 |
# | Trans9                                                | float64 |   69430 |          100   |       1130 |
# | Trans8                                                | float64 |   69430 |          100   |       1130 |
# | Trans7                                                | float64 |   69430 |          100   |       1116 |
# | Trans6                                                | float64 |   69430 |          100   |       1107 |
# | Trans5                                                | float64 |   69430 |          100   |       1068 |
# | Trans4                                                | float64 |   69430 |          100   |       1075 |
# | Trans3                                                | float64 |   69430 |          100   |       1127 |
# | Trans2                                                | float64 |   69430 |          100   |       1135 |
# | Trans1                                                | float64 |   69430 |          100   |       1135 |
# | EvapS9                                                | float64 |   69430 |          100   |       1153 |
# | EvapS8                                                | float64 |   69430 |          100   |       1155 |
# | EvapS7                                                | float64 |   69430 |          100   |       1145 |
# | EvapS6                                                | float64 |   69430 |          100   |       1135 |
# | Data.ID                                               | object  |   69430 |          100   |         51 |
# | gdp_per_capita                                        | int64   |   69430 |          100   |        496 |
# | Longitude..E.W.                                       | object  |   69430 |          100   |        254 |
# | Latitude..N.S.                                        | object  |   69430 |          100   |        251 |
# | Observation.period                                    | int64   |   69430 |          100   |         15 |
# | Location.source                                       | object  |   69430 |          100   |          9 |
# | Conversion.for.longitude                              | float64 |   69430 |          100   |        237 |
# | pr_irrigated                                          | float64 |   69428 |          100   |        191 |
# | end_date                                              | int64   |   69430 |          100   |         10 |
# | start_date                                            | int64   |   69430 |          100   |          7 |
# | Conversion.for.latitude                               | float64 |   69430 |          100   |        237 |
# | Grain.yield..tons.ha.1.                               | float64 |   69430 |          100   |      14855 |
# | AEZ                                                   | float64 |   69430 |          100   |         31 |
# | Elevation                                             | int64   |   69430 |          100   |        196 |
# | Continent                                             | object  |   69430 |          100   |          6 |
# | Country                                               | object  |   69430 |          100   |         37 |
# | Location                                              | object  |   69430 |          100   |        231 |
# | SoilM5                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM6                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM7                                                | float64 |   69343 |           99.9 |       1136 |
# | SoilM8                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM9                                                | float64 |   69343 |           99.9 |       1138 |
# | SoilM4                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM3                                                | float64 |   69343 |           99.9 |       1138 |
# | SoilM2                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM1                                                | float64 |   69343 |           99.9 |       1139 |
# | NDVI2                                                 | float64 |   69200 |           99.7 |        593 |
# | NDVI3                                                 | float64 |   69197 |           99.7 |        569 |
# | NDVI6                                                 | float64 |   69245 |           99.7 |        597 |
# | NDVI5                                                 | float64 |   69198 |           99.7 |        578 |
# | State.Region.County.Province                          | object  |   69154 |           99.6 |        132 |
# | NDVI1                                                 | float64 |   69152 |           99.6 |        568 |
# | NDVI4                                                 | float64 |   69108 |           99.5 |        560 |
# | Soil.organic.carbon..g.C.kg.1.                        | float64 |   68989 |           99.4 |        232 |
# | Soil.pH                                               | float64 |   69003 |           99.4 |        133 |
# | Sand                                                  | float64 |   68918 |           99.3 |        160 |
# | Silt                                                  | float64 |   68918 |           99.3 |        141 |
# | Clay                                                  | float64 |   68918 |           99.3 |        118 |
# | Soil_N                                                | float64 |   68840 |           99.2 |        123 |
# | NDVI7                                                 | float64 |   67785 |           97.6 |        572 |
# | NDVI8                                                 | float64 |   67762 |           97.6 |        597 |
# | NDVI9                                                 | float64 |   67784 |           97.6 |        610 |
# | Year_x                                                | float64 |   65004 |           93.6 |         15 |
# | Agricultural_Use_._Insecticides_.t.                   | float64 |   65004 |           93.6 |        123 |
# | Agricultural_Use_._Pesticides_.total._.t.             | float64 |   65004 |           93.6 |        123 |
# | Use_per_area_of_cropland_._Pesticides_.total._.kg.ha. | float64 |   65004 |           93.6 |        107 |
# | Agricultural_Use_._Herbicides_.t.                     | float64 |   64840 |           93.4 |        122 |
# | Agricultural_Use_._Fungicides_and_Bactericides_.t.    | float64 |   64840 |           93.4 |        121 |
# | N.rate..kg.N.ha.1.                                    | float64 |   63611 |           91.6 |        196 |
# | dryspells.5days.                                      | float64 |   62048 |           89.4 |        424 |
# | drydays.annualsum.                                    | float64 |   62048 |           89.4 |        444 |
# | irr_end_date                                          | float64 |   61699 |           88.9 |         10 |
# | irr_start_date                                        | float64 |   61684 |           88.8 |          8 |
# | Wheat.Type                                            | object  |   55463 |           79.9 |          2 |
# | rainfed_start_date                                    | float64 |   54978 |           79.2 |          6 |
# | rainfed_end_date                                      | float64 |   54991 |           79.2 |          9 |
# | Agricultural_Use_._Rodenticides_.t.                   | float64 |   50406 |           72.6 |         57 |
# | Mean.annual.precipitation..mm.                        | float64 |   47530 |           68.5 |        255 |
# | Crop.variety                                          | object  |   46867 |           67.5 |        943 |
# | evi_1                                                 | float64 |   45458 |           65.5 |        115 |
# | evi_2                                                 | float64 |   45467 |           65.5 |        120 |
# | evi_3                                                 | float64 |   45460 |           65.5 |        116 |
# | evi_7                                                 | float64 |   45469 |           65.5 |        120 |
# | evi_8                                                 | float64 |   45470 |           65.5 |        123 |
# | evi_9                                                 | float64 |   45473 |           65.5 |        121 |
# | Irrigation..mm.                                       | object  |   45402 |           65.4 |         31 |
# | evi_6                                                 | float64 |   45404 |           65.4 |        118 |
# | evi_5                                                 | float64 |   45411 |           65.4 |        108 |
# | irrigation_applied                                    | object  |   45402 |           65.4 |          4 |
# | evi_4                                                 | float64 |   45351 |           65.3 |        118 |
# | Pest.prescence....64                                  | object  |   44907 |           64.7 |          2 |
# | Irrigation.mm_clean                                   | float64 |   44622 |           64.3 |         26 |
# | Agricultural_Use_._Other_Pesticides_nes_.t.           | float64 |   39209 |           56.5 |         84 |
# | Soil.type                                             | object  |   36750 |           52.9 |         48 |
# | Harvesting.date.1                                     | object  |   35347 |           50.9 |        262 |
# | harvest_week                                          | float64 |   35315 |           50.9 |         42 |
# | harvest_dayofyear                                     | float64 |   35315 |           50.9 |        158 |
# | harvest_date_clean                                    | object  |   35315 |           50.9 |        260 |
# | harvest_month                                         | float64 |   35315 |           50.9 |         12 |
# | gdp                                                   | float64 |   20676 |           29.8 |        195 |
# | hdi                                                   | float64 |   20676 |           29.8 |        176 |
# | Treatment_Category                                    | object  |   18421 |           26.5 |         14 |
# | Treatment.type                                        | object  |   18421 |           26.5 |        945 |
# | Tillage.type                                          | object  |   17201 |           24.8 |         19 |
# | Treatment                                             | object  |   16052 |           23.1 |          2 |
# | Mean.annual.temperature..Â.C.                         | float64 |   15177 |           21.9 |        103 |
# | P.rate..kg.P.ha.1.                                    | float64 |   14532 |           20.9 |         61 |
# | N.type                                                | object  |   11240 |           16.2 |        648 |
# | N_Category                                            | object  |   11240 |           16.2 |         11 |
# | P.type                                                | object  |   10834 |           15.6 |         19 |
# | emissions_flag                                        | object  |   10772 |           15.5 |          2 |
# | Emissions..yes.no.                                    | object  |   10772 |           15.5 |        737 |
# | Water.regime                                          | object  |    8554 |           12.3 |          5 |
# | Plastic.film.mulching                                 | object  |    8232 |           11.9 |          2 |
# | GDDs                                                  | float64 |    6480 |            9.3 |        270 |
# | Pest.severity.score.cleaned                           | float64 |    6029 |            8.7 |         58 |
# | Pest.severity.score.......66                          | object  |    6029 |            8.7 |         60 |
# | Pest.detected...65                                    | object  |    6050 |            8.7 |          9 |
# | Planting_Week                                         | float64 |    4695 |            6.8 |         32 |
# | Planting_Day                                          | float64 |    4695 |            6.8 |         79 |
# | Planting.date.1                                       | object  |    4711 |            6.8 |        102 |
# | Planting_Month                                        | float64 |    4695 |            6.8 |         11 |
# | Planting.date                                         | object  |    4525 |            6.5 |         99 |

# %%
LAIANDFPARdata["MCD15A2H_061_FparLai_QC_MODLAND_Description"].value_counts()
# Out:
# MCD15A2H_061_FparLai_QC_MODLAND_Description
# Good quality (main algorithm with or without saturation)    154355
# Other Quality (back-up algorithm or fill values)             51403
# Name: count, dtype: int64

# %%
LAIANDFPARdata = LAIANDFPARdata[
	~LAIANDFPARdata["MCD15A2H_061_FparLai_QC_MODLAND_Description"].isin([
		"Other Quality (back-up algorithm or fill values)"
	])
]

# %%
# Select relevant columns from LAIANDFPARdata
LAIANDFPAR = LAIANDFPARdata[["Date", "Longitude", "Latitude", "MCD15A2H_061_Lai_500m", "MCD15A2H_061_Fpar_500m"]]

# %%
functions.summarize_dataframe(LAIANDFPAR)
# Out:
# | variable               | dtype   |   count |   pct_complete |   n_unique |
# |------------------------|---------|---------|----------------|------------|
# | Date                   | object  |  154355 |            100 |        830 |
# | Longitude              | float64 |  154355 |            100 |        194 |
# | Latitude               | float64 |  154355 |            100 |        195 |
# | MCD15A2H_061_Lai_500m  | float64 |  154355 |            100 |         69 |
# | MCD15A2H_061_Fpar_500m | float64 |  154355 |            100 |         94 |

# %%
LAIANDFPAR.to_csv("LAIANDFPAR.csv", index=False)

# %%
def extract_lai_fpar_variable_fast_exact(df, lai_fpar_df, var_prefix="lai_", window_length=34, variable_col='MCD15A2H_061_Lai_500m'):
    """
    Extract LAI/FPAR windows using nearest-day (±4 days) coordinate-date matches.

    Parameters:
    df: Main dataset with 'sowing_year', 'start_date', and coordinate columns
    lai_fpar_df: LAI/FPAR DataFrame with 'Date', 'Longitude', 'Latitude', and variable_col
    var_prefix: Prefix for output columns (e.g., "lai_", "fpar_")
    window_length: Number of 8-day periods (default 34 ≈ 9 months)
    variable_col: Column name for the LAI/FPAR variable

    Returns: DataFrame with sowing_year, coordinates, and extracted values
    """

    print(f"Processing {len(df)} observations with {len(lai_fpar_df)} satellite records...")

    # 1. PREPARE DATA
    lai_data = lai_fpar_df.copy()
    lai_data['Date'] = pd.to_datetime(lai_data['Date'])

    main = df.copy()
    main['start_datetime'] = pd.to_datetime(
        main['sowing_year'].astype(str) + '-' +
        main['start_date'].astype(str).str.zfill(2) + '-01'
    )

    # 2. CREATE FAST LOOKUP TABLE
    lai_lookup = lai_data.set_index(['Longitude', 'Latitude', 'Date'])[variable_col].to_dict()

    # 3. PROCESS EACH OBSERVATION
    print("Extracting values...")
    results = []

    for _, row in main.iterrows():
        lon = row['Conversion.for.longitude']
        lat = row['Conversion.for.latitude']
        start_date = row['start_datetime']

        result_row = {
            'sowing_year': row['sowing_year'],
            'Conversion.for.longitude': lon,
            'Conversion.for.latitude': lat,
            'start_date': row['start_date']
        }

        # Generate 34 target dates, 8 days apart
        for i in range(1, window_length + 1):
            target_date = start_date + timedelta(days=(i - 1) * 8)

            # Check for nearest available value within ±4 days
            nearest_val = np.nan
            for delta in range(-4, 5):  # -4 to +4 inclusive
                shifted_date = target_date + timedelta(days=delta)
                key = (lon, lat, shifted_date)
                if key in lai_lookup:
                    nearest_val = lai_lookup[key]
                    break

            result_row[f'{var_prefix}{i}'] = nearest_val

        results.append(result_row)

    # 4. RETURN RESULTS
    print("Creating final DataFrame...")
    result_df = pd.DataFrame(results)

    id_cols = ['sowing_year', 'Conversion.for.longitude', 'Conversion.for.latitude', 'start_date']
    data_cols = [f'{var_prefix}{i}' for i in range(1, window_length + 1)]
    result_df = result_df[id_cols + data_cols]

    print(f"✓ Complete! Processed {len(result_df)} observations with {window_length} time steps each.")
    return result_df

# %%
#Run the extraction functions

LAI = extract_lai_fpar_variable_fast_exact(data, LAIANDFPAR, var_prefix="lai_", window_length=34, variable_col='MCD15A2H_061_Lai_500m')

FPAR = extract_lai_fpar_variable_fast_exact(data, LAIANDFPAR, var_prefix="fpar_", window_length=34, variable_col='MCD15A2H_061_Fpar_500m')


FPAR.to_csv("FPAR.csv", index=False)

LAI.to_csv("LAI.csv", index=False)
# Out:
# Processing 69430 observations with 154355 satellite records...
# Extracting values...
# Creating final DataFrame...
# ✓ Complete! Processed 69430 observations with 34 time steps each.
# Processing 69430 observations with 154355 satellite records...
# Extracting values...
# Creating final DataFrame...
# ✓ Complete! Processed 69430 observations with 34 time steps each.

# %% [markdown]
# CREATING MONTHLY WINDOWS FOR EASY JOINING

# %%
def collapse_time_windows(df, var_prefix='lai_', n_bins=8):
    """
    Collapse 34 LAI/FPAR windows into ~monthly averages.

    Parameters:
    - df: DataFrame with columns like 'lai_1' to 'lai_34' or 'fpar_1' to 'fpar_34'
    - var_prefix: 'lai_' or 'fpar_'
    - n_bins: number of collapsed bins (default = 8)

    Returns:
    - DataFrame with collapsed columns named like 'lai_month_1' to 'lai_month_8'
    """
    window_cols = [f"{var_prefix}{i}" for i in range(1, 35)]
    collapsed = pd.DataFrame(index=df.index)

    group_size = int(np.ceil(len(window_cols) / n_bins))

    for i in range(n_bins):
        group = window_cols[i * group_size: (i + 1) * group_size]
        collapsed[f"{var_prefix}month_{i+1}"] = df[group].mean(axis=1)

    return pd.concat([df.drop(columns=window_cols), collapsed], axis=1)

# %%
LAI_monthly = collapse_time_windows(LAI, var_prefix='lai_', n_bins=8)
FPAR_monthly = collapse_time_windows(FPAR, var_prefix='fpar_', n_bins=8)

# %%
LAI_monthly = LAI_monthly.drop_duplicates()
FPAR_monthly = FPAR_monthly.drop_duplicates()

# %%
FPAR_monthly.to_csv("FPAR_monthly.csv", index=False)

LAI_monthly.to_csv("LAI_monthly.csv", index=False)

# %%
functions.summarize_dataframe(LAI_monthly)
# Out:
# | variable                 | dtype   |   count |   pct_complete |   n_unique |
# |--------------------------|---------|---------|----------------|------------|
# | sowing_year              | int64   |   69430 |          100   |         15 |
# | Conversion.for.longitude | float64 |   69430 |          100   |        237 |
# | Conversion.for.latitude  | float64 |   69430 |          100   |        237 |
# | start_date               | int64   |   69430 |          100   |          7 |
# | lai_month_6              | float64 |   67871 |           97.8 |        181 |
# | lai_month_7              | float64 |   67871 |           97.8 |        185 |
# | lai_month_1              | float64 |   67866 |           97.7 |        169 |
# | lai_month_5              | float64 |   67758 |           97.6 |        163 |
# | lai_month_4              | float64 |   67456 |           97.2 |        161 |
# | lai_month_3              | float64 |   67380 |           97   |        140 |
# | lai_month_2              | float64 |   65100 |           93.8 |        126 |
# | lai_month_8              | float64 |       0 |            0   |          0 |

# %%
data2 = data1.merge(LAI_monthly, on=['sowing_year', 'Conversion.for.longitude', 'Conversion.for.latitude', 'start_date'], how='left')

# %%
functions.summarize_dataframe(data2)
# Out:
# | variable                                              | dtype   |   count |   pct_complete |   n_unique |
# |-------------------------------------------------------|---------|---------|----------------|------------|
# | id                                                    | int64   |   69430 |          100   |      69036 |
# | EvapS3                                                | float64 |   69430 |          100   |       1155 |
# | EvapS1                                                | float64 |   69430 |          100   |       1155 |
# | pre9                                                  | float64 |   69428 |          100   |        639 |
# | pre8                                                  | float64 |   69428 |          100   |        632 |
# | pre7                                                  | float64 |   69428 |          100   |        650 |
# | pre6                                                  | float64 |   69428 |          100   |        674 |
# | pre5                                                  | float64 |   69428 |          100   |        660 |
# | pre4                                                  | float64 |   69428 |          100   |        659 |
# | pre3                                                  | float64 |   69428 |          100   |        654 |
# | pre2                                                  | float64 |   69428 |          100   |        644 |
# | pre1                                                  | float64 |   69428 |          100   |        632 |
# | temp9                                                 | float64 |   69428 |          100   |        684 |
# | temp8                                                 | float64 |   69428 |          100   |        679 |
# | temp7                                                 | float64 |   69428 |          100   |        678 |
# | temp6                                                 | float64 |   69428 |          100   |        679 |
# | temp5                                                 | float64 |   69428 |          100   |        678 |
# | temp4                                                 | float64 |   69428 |          100   |        677 |
# | temp3                                                 | float64 |   69428 |          100   |        673 |
# | temp2                                                 | float64 |   69428 |          100   |        660 |
# | temp1                                                 | float64 |   69428 |          100   |        652 |
# | Data.ID                                               | object  |   69430 |          100   |         51 |
# | latitude_jittered                                     | float64 |   69430 |          100   |      69430 |
# | jitter_radius_km                                      | float64 |   69430 |          100   |         88 |
# | group_id                                              | object  |   69430 |          100   |        572 |
# | EvapS2                                                | float64 |   69430 |          100   |       1155 |
# | EvapS4                                                | float64 |   69430 |          100   |       1146 |
# | year                                                  | int64   |   69430 |          100   |         15 |
# | EvapS5                                                | float64 |   69430 |          100   |       1118 |
# | Evap9                                                 | float64 |   69430 |          100   |        565 |
# | Evap8                                                 | float64 |   69430 |          100   |        565 |
# | Evap7                                                 | float64 |   69430 |          100   |        565 |
# | Evap6                                                 | float64 |   69430 |          100   |        565 |
# | Evap5                                                 | float64 |   69430 |          100   |        565 |
# | Evap4                                                 | float64 |   69430 |          100   |        565 |
# | Evap3                                                 | float64 |   69430 |          100   |        565 |
# | Evap2                                                 | float64 |   69430 |          100   |        565 |
# | Evap1                                                 | float64 |   69430 |          100   |        565 |
# | sowing_year                                           | int64   |   69430 |          100   |         15 |
# | Trans9                                                | float64 |   69430 |          100   |       1130 |
# | Trans8                                                | float64 |   69430 |          100   |       1130 |
# | Trans7                                                | float64 |   69430 |          100   |       1116 |
# | Trans6                                                | float64 |   69430 |          100   |       1107 |
# | Trans5                                                | float64 |   69430 |          100   |       1068 |
# | Trans4                                                | float64 |   69430 |          100   |       1075 |
# | Trans3                                                | float64 |   69430 |          100   |       1127 |
# | Trans2                                                | float64 |   69430 |          100   |       1135 |
# | Trans1                                                | float64 |   69430 |          100   |       1135 |
# | EvapS9                                                | float64 |   69430 |          100   |       1153 |
# | EvapS8                                                | float64 |   69430 |          100   |       1155 |
# | EvapS7                                                | float64 |   69430 |          100   |       1145 |
# | EvapS6                                                | float64 |   69430 |          100   |       1135 |
# | gdp_per_capita                                        | int64   |   69430 |          100   |        496 |
# | longitude_jittered                                    | float64 |   69430 |          100   |      69430 |
# | Location                                              | object  |   69430 |          100   |        231 |
# | Grain.yield..tons.ha.1.                               | float64 |   69430 |          100   |      14855 |
# | Conversion.for.latitude                               | float64 |   69430 |          100   |        237 |
# | Elevation                                             | int64   |   69430 |          100   |        196 |
# | Country                                               | object  |   69430 |          100   |         37 |
# | Continent                                             | object  |   69430 |          100   |          6 |
# | AEZ                                                   | float64 |   69430 |          100   |         31 |
# | Conversion.for.longitude                              | float64 |   69430 |          100   |        237 |
# | pr_irrigated                                          | float64 |   69428 |          100   |        191 |
# | Location.source                                       | object  |   69430 |          100   |          9 |
# | Observation.period                                    | int64   |   69430 |          100   |         15 |
# | end_date                                              | int64   |   69430 |          100   |         10 |
# | start_date                                            | int64   |   69430 |          100   |          7 |
# | Latitude..N.S.                                        | object  |   69430 |          100   |        251 |
# | Longitude..E.W.                                       | object  |   69430 |          100   |        254 |
# | SoilM8                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM5                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM4                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM6                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM1                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM7                                                | float64 |   69343 |           99.9 |       1136 |
# | SoilM2                                                | float64 |   69343 |           99.9 |       1139 |
# | SoilM9                                                | float64 |   69343 |           99.9 |       1138 |
# | SoilM3                                                | float64 |   69343 |           99.9 |       1138 |
# | NDVI2                                                 | float64 |   69200 |           99.7 |        593 |
# | NDVI3                                                 | float64 |   69197 |           99.7 |        569 |
# | NDVI5                                                 | float64 |   69198 |           99.7 |        578 |
# | NDVI6                                                 | float64 |   69245 |           99.7 |        597 |
# | State.Region.County.Province                          | object  |   69154 |           99.6 |        132 |
# | NDVI1                                                 | float64 |   69152 |           99.6 |        568 |
# | NDVI4                                                 | float64 |   69108 |           99.5 |        560 |
# | Soil.pH                                               | float64 |   69003 |           99.4 |        133 |
# | Soil.organic.carbon..g.C.kg.1.                        | float64 |   68989 |           99.4 |        232 |
# | Sand                                                  | float64 |   68918 |           99.3 |        160 |
# | Silt                                                  | float64 |   68918 |           99.3 |        141 |
# | Clay                                                  | float64 |   68918 |           99.3 |        118 |
# | Soil_N                                                | float64 |   68840 |           99.2 |        123 |
# | lai_month_6                                           | float64 |   67871 |           97.8 |        181 |
# | lai_month_7                                           | float64 |   67871 |           97.8 |        185 |
# | lai_month_1                                           | float64 |   67866 |           97.7 |        169 |
# | NDVI9                                                 | float64 |   67784 |           97.6 |        610 |
# | lai_month_5                                           | float64 |   67758 |           97.6 |        163 |
# | NDVI7                                                 | float64 |   67785 |           97.6 |        572 |
# | NDVI8                                                 | float64 |   67762 |           97.6 |        597 |
# | lai_month_4                                           | float64 |   67456 |           97.2 |        161 |
# | lai_month_3                                           | float64 |   67380 |           97   |        140 |
# | lai_month_2                                           | float64 |   65100 |           93.8 |        126 |
# | Year_x                                                | float64 |   65004 |           93.6 |         15 |
# | Agricultural_Use_._Insecticides_.t.                   | float64 |   65004 |           93.6 |        123 |
# | Agricultural_Use_._Pesticides_.total._.t.             | float64 |   65004 |           93.6 |        123 |
# | Use_per_area_of_cropland_._Pesticides_.total._.kg.ha. | float64 |   65004 |           93.6 |        107 |
# | Agricultural_Use_._Fungicides_and_Bactericides_.t.    | float64 |   64840 |           93.4 |        121 |
# | Agricultural_Use_._Herbicides_.t.                     | float64 |   64840 |           93.4 |        122 |
# | N.rate..kg.N.ha.1.                                    | float64 |   63611 |           91.6 |        196 |
# | dryspells.5days.                                      | float64 |   62048 |           89.4 |        424 |
# | drydays.annualsum.                                    | float64 |   62048 |           89.4 |        444 |
# | irr_end_date                                          | float64 |   61699 |           88.9 |         10 |
# | irr_start_date                                        | float64 |   61684 |           88.8 |          8 |
# | Wheat.Type                                            | object  |   55463 |           79.9 |          2 |
# | rainfed_start_date                                    | float64 |   54978 |           79.2 |          6 |
# | rainfed_end_date                                      | float64 |   54991 |           79.2 |          9 |
# | Agricultural_Use_._Rodenticides_.t.                   | float64 |   50406 |           72.6 |         57 |
# | Mean.annual.precipitation..mm.                        | float64 |   47530 |           68.5 |        255 |
# | Crop.variety                                          | object  |   46867 |           67.5 |        943 |
# | evi_1                                                 | float64 |   45458 |           65.5 |        115 |
# | evi_7                                                 | float64 |   45469 |           65.5 |        120 |
# | evi_9                                                 | float64 |   45473 |           65.5 |        121 |
# | evi_2                                                 | float64 |   45467 |           65.5 |        120 |
# | evi_3                                                 | float64 |   45460 |           65.5 |        116 |
# | evi_8                                                 | float64 |   45470 |           65.5 |        123 |
# | Irrigation..mm.                                       | object  |   45402 |           65.4 |         31 |
# | irrigation_applied                                    | object  |   45402 |           65.4 |          4 |
# | evi_5                                                 | float64 |   45411 |           65.4 |        108 |
# | evi_6                                                 | float64 |   45404 |           65.4 |        118 |
# | evi_4                                                 | float64 |   45351 |           65.3 |        118 |
# | Pest.prescence....64                                  | object  |   44907 |           64.7 |          2 |
# | Irrigation.mm_clean                                   | float64 |   44622 |           64.3 |         26 |
# | Agricultural_Use_._Other_Pesticides_nes_.t.           | float64 |   39209 |           56.5 |         84 |
# | Soil.type                                             | object  |   36750 |           52.9 |         48 |
# | harvest_month                                         | float64 |   35315 |           50.9 |         12 |
# | Harvesting.date.1                                     | object  |   35347 |           50.9 |        262 |
# | harvest_week                                          | float64 |   35315 |           50.9 |         42 |
# | harvest_dayofyear                                     | float64 |   35315 |           50.9 |        158 |
# | harvest_date_clean                                    | object  |   35315 |           50.9 |        260 |
# | gdp                                                   | float64 |   20676 |           29.8 |        195 |
# | hdi                                                   | float64 |   20676 |           29.8 |        176 |
# | Treatment.type                                        | object  |   18421 |           26.5 |        945 |
# | Treatment_Category                                    | object  |   18421 |           26.5 |         14 |
# | Tillage.type                                          | object  |   17201 |           24.8 |         19 |
# | Treatment                                             | object  |   16052 |           23.1 |          2 |
# | Mean.annual.temperature..Â.C.                         | float64 |   15177 |           21.9 |        103 |
# | P.rate..kg.P.ha.1.                                    | float64 |   14532 |           20.9 |         61 |
# | N_Category                                            | object  |   11240 |           16.2 |         11 |
# | N.type                                                | object  |   11240 |           16.2 |        648 |
# | P.type                                                | object  |   10834 |           15.6 |         19 |
# | emissions_flag                                        | object  |   10772 |           15.5 |          2 |
# | Emissions..yes.no.                                    | object  |   10772 |           15.5 |        737 |
# | Water.regime                                          | object  |    8554 |           12.3 |          5 |
# | Plastic.film.mulching                                 | object  |    8232 |           11.9 |          2 |
# | GDDs                                                  | float64 |    6480 |            9.3 |        270 |
# | Pest.severity.score.......66                          | object  |    6029 |            8.7 |         60 |
# | Pest.severity.score.cleaned                           | float64 |    6029 |            8.7 |         58 |
# | Pest.detected...65                                    | object  |    6050 |            8.7 |          9 |
# | Planting_Day                                          | float64 |    4695 |            6.8 |         79 |
# | Planting.date.1                                       | object  |    4711 |            6.8 |        102 |
# | Planting_Month                                        | float64 |    4695 |            6.8 |         11 |
# | Planting_Week                                         | float64 |    4695 |            6.8 |         32 |
# | Planting.date                                         | object  |    4525 |            6.5 |         99 |
# | lai_month_8                                           | float64 |       0 |            0   |          0 |

# %%
data3 = data2.merge(FPAR_monthly, on=['sowing_year', 'Conversion.for.longitude', 'Conversion.for.latitude', 'start_date'], how='left')

# %%
data3.to_csv("../../../../data/finaldatasets/testdata/finalfr/AlphaTree.csv", index=False)
